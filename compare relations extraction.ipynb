# %%
import nltk
import os
from warnings import filterwarnings
filterwarnings("ignore")
os.environ['JAVAHOME'] = 'C://Users//felix//jdk-12.0.2'

# %%
# load the data
# with open("review_0408.txt","r") as f:
#     lines = [l.strip()[0:-2] for l in f.readlines()]
#     lines = [l.lower() for l in lines if l!=""]
# print(len(lines))

with open("movies_com.txt","r") as f:
    lines = [l.strip() for l in f.readlines()]
    lines = [l.lower() for l in lines if l!=""]
print(len(lines))
# Out:
# 238

# %%
#定义依存分析器
from nltk.parse.stanford import StanfordDependencyParser
path_to_jar = './stanford-parser-full-2018-10-17/stanford-parser.jar'
path_to_models_jar = './stanford-parser-full-2018-10-17/stanford-parser-3.9.2-models.jar'
dep_parser = StanfordDependencyParser(path_to_jar, path_to_models_jar)

#列举前5个依存分析结果
for line in lines[0:5]:
    print(line)
    res = dep_parser.raw_parse(line).__next__()
    for row in res.triples():
        print(row)
    print()


# 结论：识别后，电影名无法看出来，如infinity war被拆开
# Out:
# avengers infinity war was way better than avengers endgame in terms of their stories.
# (('endgame', 'JJ'), 'nsubj', ('war', 'NN'))
# (('war', 'NN'), 'amod', ('avengers', 'JJ'))
# (('war', 'NN'), 'compound', ('infinity', 'NN'))
# (('endgame', 'JJ'), 'cop', ('was', 'VBD'))
# (('endgame', 'JJ'), 'advmod', ('better', 'RBR'))
# (('better', 'RBR'), 'advmod', ('way', 'RB'))
# (('better', 'RBR'), 'nmod', ('avengers', 'NNS'))
# (('avengers', 'NNS'), 'case', ('than', 'IN'))
# (('endgame', 'JJ'), 'nmod', ('terms', 'NNS'))
# (('terms', 'NNS'), 'case', ('in', 'IN'))
# (('terms', 'NNS'), 'nmod', ('stories', 'NNS'))
# (('stories', 'NNS'), 'case', ('of', 'IN'))
# (('stories', 'NNS'), 'nmod:poss', ('their', 'PRP$'))
#
# avengers infinity war is preferred because the production design is more refined than avengers endgame.
# (('preferred', 'VBN'), 'nsubjpass', ('war', 'NN'))
# (('war', 'NN'), 'amod', ('avengers', 'JJ'))
# (('war', 'NN'), 'compound', ('infinity', 'NN'))
# (('preferred', 'VBN'), 'auxpass', ('is', 'VBZ'))
# (('preferred', 'VBN'), 'advcl', ('refined', 'VBN'))
# (('refined', 'VBN'), 'mark', ('because', 'IN'))
# (('refined', 'VBN'), 'nsubjpass', ('design', 'NN'))
# (('design', 'NN'), 'det', ('the', 'DT'))
# (('design', 'NN'), 'compound', ('production', 'NN'))
# (('refined', 'VBN'), 'auxpass', ('is', 'VBZ'))
# (('refined', 'VBN'), 'advmod', ('more', 'RBR'))
# (('refined', 'VBN'), 'nmod', ('endgame', 'NN'))
# (('endgame', 'NN'), 'case', ('than', 'IN'))
# (('endgame', 'NN'), 'amod', ('avengers', 'JJ'))
#
# i donot like the avengers endgame because the script is not as good as avengers infinity war.
# (('donot', 'VBP'), 'nsubj', ('i', 'FW'))
# (('donot', 'VBP'), 'advcl', ('endgame', 'VBP'))
# (('endgame', 'VBP'), 'mark', ('like', 'IN'))
# (('endgame', 'VBP'), 'nsubj', ('avengers', 'NNS'))
# (('avengers', 'NNS'), 'det', ('the', 'DT'))
# (('endgame', 'VBP'), 'advcl', ('good', 'JJ'))
# (('good', 'JJ'), 'mark', ('because', 'IN'))
# (('good', 'JJ'), 'nsubj', ('script', 'NN'))
# (('script', 'NN'), 'det', ('the', 'DT'))
# (('good', 'JJ'), 'cop', ('is', 'VBZ'))
# (('good', 'JJ'), 'neg', ('not', 'RB'))
# (('good', 'JJ'), 'advmod', ('as', 'RB'))
# (('good', 'JJ'), 'nmod', ('war', 'NN'))
# (('war', 'NN'), 'case', ('as', 'IN'))
# (('war', 'NN'), 'amod', ('avengers', 'JJ'))
# (('war', 'NN'), 'amod', ('infinity', 'JJ'))
#
# avengers infinity war has better interaction with audience than the avengers endgame.
# (('interaction', 'VBN'), 'nsubj', ('war', 'NN'))
# (('war', 'NN'), 'amod', ('avengers', 'JJ'))
# (('war', 'NN'), 'compound', ('infinity', 'NN'))
# (('interaction', 'VBN'), 'aux', ('has', 'VBZ'))
# (('interaction', 'VBN'), 'advmod', ('better', 'RBR'))
# (('interaction', 'VBN'), 'nmod', ('audience', 'NN'))
# (('audience', 'NN'), 'case', ('with', 'IN'))
# (('interaction', 'VBN'), 'nmod', ('endgame', 'NN'))
# (('endgame', 'NN'), 'case', ('than', 'IN'))
# (('endgame', 'NN'), 'det', ('the', 'DT'))
# (('endgame', 'NN'), 'amod', ('avengers', 'JJ'))
#
# avengers endgame has significantly more special effects in directing than avengers endgame.
# (('has', 'VBZ'), 'nsubj', ('avengers', 'NNS'))
# (('has', 'VBZ'), 'advmod', ('endgame', 'RB'))
# (('has', 'VBZ'), 'dobj', ('effects', 'NNS'))
# (('effects', 'NNS'), 'amod', ('more', 'JJR'))
# (('more', 'JJR'), 'advmod', ('significantly', 'RB'))
# (('effects', 'NNS'), 'amod', ('special', 'JJ'))
# (('effects', 'NNS'), 'acl', ('directing', 'VBG'))
# (('directing', 'VBG'), 'mark', ('in', 'IN'))
# (('directing', 'VBG'), 'nmod', ('endgame', 'NN'))
# (('endgame', 'NN'), 'case', ('than', 'IN'))
# (('endgame', 'NN'), 'amod', ('avengers', 'JJ'))

# %%
# 定义命名实体识别器
from nltk.tag import StanfordNERTagger
ent_tagger = StanfordNERTagger("./stanford-ner-2018-10-16/classifiers/english.conll.4class.distsim.crf.ser.gz","./stanford-ner-2018-10-16/stanford-ner.jar")

#输出前5个实体识别结果，期望能找出电影名
for line in lines[0:5]:
    line = line.split()
    print(ent_tagger.tag(line))
    print()
    
#结论：识别效果不佳，应该需要自己训练适当的识别器
# Out:
# [('avengers', 'O'), ('infinity', 'O'), ('war', 'O'), ('was', 'O'), ('way', 'O'), ('better', 'O'), ('than', 'O'), ('avengers', 'O'), ('endgame', 'O'), ('in', 'O'), ('terms', 'O'), ('of', 'O'), ('their', 'O'), ('stories.', 'O')]
#
# [('avengers', 'O'), ('infinity', 'O'), ('war', 'O'), ('is', 'O'), ('preferred', 'O'), ('because', 'O'), ('the', 'O'), ('production', 'O'), ('design', 'O'), ('is', 'O'), ('more', 'O'), ('refined', 'O'), ('than', 'O'), ('avengers', 'O'), ('endgame.', 'O')]
#
# [('i', 'O'), ('donot', 'O'), ('like', 'O'), ('the', 'O'), ('avengers', 'O'), ('endgame', 'O'), ('because', 'O'), ('the', 'O'), ('script', 'O'), ('is', 'O'), ('not', 'O'), ('as', 'O'), ('good', 'O'), ('as', 'O'), ('avengers', 'O'), ('infinity', 'O'), ('war.', 'O')]
#
# [('avengers', 'O'), ('infinity', 'O'), ('war', 'O'), ('has', 'O'), ('better', 'O'), ('interaction', 'O'), ('with', 'O'), ('audience', 'O'), ('than', 'O'), ('the', 'O'), ('avengers', 'O'), ('endgame.', 'O')]
#
# [('avengers', 'O'), ('endgame', 'O'), ('has', 'O'), ('significantly', 'O'), ('more', 'O'), ('special', 'O'), ('effects', 'O'), ('in', 'O'), ('directing', 'O'), ('than', 'O'), ('avengers', 'O'), ('endgame.', 'O')]

# %%
#句法分析
from nltk.chunk.regexp import *
chunk_rules = ChunkRule("<.*>+", "chunk everything")
reg_parser = RegexpParser('''
        NP: {<JJ>* <NN>* <NNS>*}                           
''')

for line in lines[0:5]:
    res = reg_parser.parse(nltk.pos_tag(nltk.word_tokenize(line)))
    for row in res:
        print(row)
    print()
    res.draw()
# Out:
# (NP avengers/NNS)
# ('infinity', 'VBP')
# (NP war/NN)
# ('was', 'VBD')
# (NP way/NN)
# ('better', 'RBR')
# ('than', 'IN')
# (NP avengers/NNS)
# ('endgame', 'VBP')
# ('in', 'IN')
# (NP terms/NNS)
# ('of', 'IN')
# ('their', 'PRP$')
# (NP stories/NNS)
# ('.', '.')
#
# (NP avengers/NNS)
# (NP infinity/JJ war/NN)
# ('is', 'VBZ')
# ('preferred', 'VBN')
# ('because', 'IN')
# ('the', 'DT')
# (NP production/NN design/NN)
# ('is', 'VBZ')
# ('more', 'RBR')
# (NP refined/JJ)
# ('than', 'IN')
# (NP avengers/NNS)
# ('endgame', 'VBP')
# ('.', '.')
#
# ('i', 'RB')
# ('donot', 'VBP')
# ('like', 'IN')
# ('the', 'DT')
# (NP avengers/NNS)
# ('endgame', 'VBP')
# ('because', 'IN')
# ('the', 'DT')
# (NP script/NN)
# ('is', 'VBZ')
# ('not', 'RB')
# ('as', 'RB')
# (NP good/JJ)
# ('as', 'IN')
# (NP avengers/NNS)
# (NP infinity/JJ war/NN)
# ('.', '.')
#
# (NP avengers/NNS)
# (NP infinity/NN war/NN)
# ('has', 'VBZ')
# ('better', 'JJR')
# (NP interaction/NN)
# ('with', 'IN')
# (NP audience/NN)
# ('than', 'IN')
# ('the', 'DT')
# (NP avengers/NNS)
# ('endgame', 'VBP')
# ('.', '.')

# %%
sentence = 'the avengers is better than transformers in the storyline'
re = reg_parser.parse(nltk.pos_tag(nltk.word_tokenize(sentence)))
re.draw()

# %% [markdown]
# # 观察数据，提取规则
#
# # 词相关规则
# ## 更好 a比b好
# a better than b
# a best
# a more x/none than b
# perfer a to b
# a won b
# ：前面有not，则b比a好
#
# b lack/lacking to a
# b inferior to a
# b less than a
#
#
#
#
# # 句法相关规则
# 所有NP作为备选的movie title，然后用文档频率值过滤
#
# # 依存分析相关规则
# 未找到有效规则

# %%
# self defined grammer, dependency relation

# %%
# 所有NP作为备选的movie title
nps=[]
for line in lines:
    res = reg_parser.parse(nltk.pos_tag(nltk.word_tokenize(line)))
    for row in res:
        if str(type(row))!="<class 'tuple'>":
            phrase = [w[0] for w in row]
#             print(phrase)
            nps.append(" ".join(phrase))
    #print()

nps = set(nps)
print(len(nps))
# Out:
# 202

# %%
# 用文档频率值过滤
phrase_count = {}
for phrase in nps:
    if len(phrase.split())==1:
        count = sum([1 if phrase in line.split() else 0 for line in lines])
    else:
        count = sum([1 if phrase in line else 0 for line in lines])
    phrase_count[phrase]=count

# 阈值设为10
thres = 10
phrases = []
for key,val in phrase_count.items():
    if val>=thres:
        phrases.append(key)

print(len(phrases))
print(phrases)


# 去重
movies = []
for i in phrases:
    flag=True
    for j in phrases:
        if i==j:
            continue
        if i in j.split():
            flag=False
            break
    if flag:
        movies.append(i)
print()
print(len(movies))
print(movies)

# 过滤pair(最后要比较的对），如果一个movie名称与（几乎）其它所有名称同时出现，则去掉这个名称，如“movie”，“I”
compare_movies=[]
while len(movies)!=len(compare_movies):
    max_count = 0
    mcount = {}
    for m in movies:
        count=0
        for n in movies:
            if m==n:
                continue
            for line in lines:
                if m in line and n in line:
                    count+=1
                    break
        mcount[m]=count
    max_count = max(list(mcount.values()))
    for m,count in mcount.items():
        if count>len(movies)*0.5 and count==max_count:
            continue
        else:
            compare_movies.append(m)
    if len(movies)!=len(compare_movies):
        movies = compare_movies.copy()
        compare_movies=[]
print()
print(len(compare_movies))
print(compare_movies)
# Out:
# 24
# ['fantastic', 'way', 'avengers', 'good', 'movie', 'terms', 'transformers', 'i', 'captain america', 'infinity', 'iron man', 'america', 'war', 'plot', 'endgame', 'marvel', 'stories', 'story', 'man', 'line', 'infinity war', 'much', 'captain marvel', 'captain']
#
# 18
# ['fantastic', 'way', 'avengers', 'good', 'movie', 'terms', 'transformers', 'i', 'captain america', 'iron man', 'plot', 'endgame', 'stories', 'story', 'line', 'infinity war', 'much', 'captain marvel']
#
# 6
# ['transformers', 'captain america', 'iron man', 'endgame', 'infinity war', 'captain marvel']

# %%
# a vs b
def countvs(a,b):
    total = 0.0
    better,worse=0.0,0.0
    for line in lines:
        pa=line.find(a)
        pb=line.find(b)
        if pa==-1 or pb==-1:
            continue
        nott=line.find("not ")
        for x in ["better","best","more","prefer","won","win","beat","outstrip","defeat","outperform","top","first rate","more enjoyable","more fascinating","more pleasant","absorbing"]:
            r1=line.find(x)
            if r1!=-1:
                if nott==-1:
                    if pa<r1 and pb>r1:
                        better+=1
                    elif pb<r1 and pa>r1:
                        worse+=1
                elif nott!=-1 and nott<r1:
                    if pa<r1 and pb>r1:
                        worse+=1
                    elif pb<r1 and pa>r1:
                        better+=1
        for x in ["lack","lacking","inferior","worse","less","least","second-rate", "third-rate", "outdated",'silly','boring','disappointing',"weak"]:
            r2=line.find(x)
            if r2!=-1:
                if nott==-1:
                    if pa<r1 and pb>r1:
                        worse+=1
                    elif pb<r1 and pa>r1:
                        better+=1
        total+=1
    #print(better,worse,total)
    return (better,worse,total)
                
compare = {}
for a in compare_movies:
    val = 0 #tie
    for b in compare_movies:
        if a==b or a+'_'+b in compare or b+'_'+a in compare:
            continue
        result = countvs(a,b)
        if result[2]>0:
            print(a+" vs. "+b)
            print('better','worse','total :',result)
            compare[a+'_'+b]=(result[0]/result[2],result[1]/result[2])
            print("there are {:.2%}/{:.2%} people think {} is better/worse than {}.".format(compare[a+'_'+b][0],compare[a+'_'+b][1],a,b))
# Out:
# transformers vs. iron man
# better worse total : (10.0, 23.0, 49.0)
# there are 20.41%/46.94% people think transformers is better/worse than iron man.
# captain america vs. captain marvel
# better worse total : (21.0, 24.0, 77.0)
# there are 27.27%/31.17% people think captain america is better/worse than captain marvel.
# endgame vs. infinity war
# better worse total : (7.0, 44.0, 91.0)
# there are 7.69%/48.35% people think endgame is better/worse than infinity war.
